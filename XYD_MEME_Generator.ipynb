# %%
# !pip install openai

# %%
import json
import random
import requests
from openai import OpenAI
import urllib.request
from IPython.display import Image, display

# OpenAI API key
client = OpenAI(api_key = "YOUR OPENAI KEY")

art_styles = ["Impressionism", "Surrealism", "Abstract Expressionism", "Realism", "Classicism", "Romanticism", "Fauvism", "Cubism", "Expressionism", "Minimalism", "Pointillism", "Neoclassicism", "Pop Art", "Symbolism", "Art Deco", "Baroque", "Renaissance", "Graffiti Art", "Futurism", "Chinese Ink Painting", "Dadaism", "Post-Impressionism", "Constructivism", "Photorealism", "Hyperrealism", "Suprematism", "Abstract Art", "Op Art", "Art Nouveau", "Digital Art", "Street Art", "Contemporary Art", "Naïve Art", "Outsider Art", "Kinetic Art", "Conceptual Art", "Mannerism", "Magic Realism", "Precisionism", "Regionalism", "Academic Art", "Synthetism", "Hard-edge Painting", "Stencil Art", "Anime/Manga Art", "Traditional Japanese Ukiyo-e", "Aboriginal Art", "Gothic Art", "Byzantine Art", "Medieval Art", "Pre-Raphaelite", "Victorian Art", "Tonalism", "Cloisonnism", "De Stijl", "Color Field Painting", "Ashcan School", "Social Realism", "New Objectivity", "Metaphysical Art", "Neo-expressionism", "Lowbrow Art", "Postmodern Art", "Earth Art (Land Art)", "Performance Art", "Installation Art", "Collage Art", "Assemblage", "Primitivism", "Neo-Dada", "Vorticism", "Orientalism", "Socialist Realism", "Luminism", "Les Nabis", "Divisionism", "Figurative Art", "Calligraphy Art", "Fantasy Art", "Steampunk Art", "Cyberpunk Art", "Biomorphic Art", "Neo-Pop", "New Media Art", "Street Muralism", "Chiaroscuro", "Ink Wash Painting", "Encaustic Painting", "Watercolor Painting", "Oil Painting", "Acrylic Painting", "Tempera Painting", "Pastel Painting", "Spray Painting", "Action Painting", "Digital Illustration", "Pixel Art", "Sumi-e"]

fashion_accessories = ["Sunglasses", "Handbag", "Tote Bag", "Clutch", "Backpack", "Shoulder Bag", "Wallet", "Purse", "Watch", "Bracelet", "Charm Bracelet", "Bangle", "Anklet", "Necklace", "Choker", "Pendant", "Brooch", "Pin", "Earrings", "Stud Earrings", "Hoop Earrings", "Drop Earrings", "Ring", "Cocktail Ring", "Midi Ring", "Hairband", "Headband", "Bandana", "Scarf", "Silk Scarf", "Wool Scarf", "Infinity Scarf", "Necktie", "Bow Tie", "Ascot Tie", "Pocket Square", "Cufflinks", "Tie Clip", "Suspenders", "Belt", "Leather Belt", "Chain Belt", "Waist Belt", "Gloves", "Leather Gloves", "Winter Gloves", "Driving Gloves", "Mittens", "Hat", "Fedora", "Beanie", "Baseball Cap", "Bucket Hat", "Beret", "Visor", "Sun Hat", "Panama Hat", "Cowboy Hat", "Fascinator", "Hair Clip", "Barrette", "Hairpin", "Hair Tie", "Scrunchie", "Hair Comb", "Tiara", "Crown", "Veil", "Umbrella", "Parasols", "Face Mask", "Shawl", "Cape", "Poncho", "Keychain", "Lapel Pin", "Phone Case", "Smartwatch", "Fitness Tracker", "Charm", "Badge", "Boot Covers", "Leg Warmers", "Sock Garters", "Shoe Clips", "Eyeglass Chain", "Sunglass Strap", "Money Clip", "Document Holder", "Luggage Tag", "Travel Pillow", "Ear Muffs", "Card Holder", "Arm Warmers", "Pashmina", "Brooch Pin", "Sweater Clip", "Wristband"]

# randomly choose art style
style = random.choice(art_styles)

# randomly choose 4 accessories
accessories = random.sample(fashion_accessories, 4)
acc1, acc2, acc3, acc4 = accessories

# generate prompt
prompt = f"A cute yellow duckie (based on the rubber duck) in {style} style, wearing {acc1}, {acc2}, {acc3}, and {acc4}. The background is also in {style} style."

print(prompt)

# use DALL-E 3 API to generate image
response = client.images.generate(
    model="dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="standard",
    n=1
)

# capture image url
image_url = response.data[0].url
print("Generated image URL:", image_url)

# Retrieving the resource located at the URL
# and storing it in the file name a.png
urllib.request.urlretrieve(image_url, "img.png")

# Opening the image and displaying it (to confirm its presence)
display(Image('img.png'))
# Out:
# A cute yellow duckie (based on the rubber duck) in De Stijl style, wearing Ring, Sunglass Strap, Luggage Tag, and Wool Scarf. The background is also in De Stijl style.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-TfKSikmePP1YTTcdhM0UF7Qm/user-rmQTVgtOLhnrgw4P9T8f92IW/img-IhWk70ILsdweKMM9Kx3UcdMe.png?st=2025-03-16T17%3A43%3A37Z&se=2025-03-16T19%3A43%3A37Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-03-16T18%3A43%3A37Z&ske=2025-03-17T18%3A43%3A37Z&sks=b&skv=2024-08-04&sig=MikNUmbfsV5b09RNIJYCSb%2BQ6deEx8x4Ja2YpnFC6wI%3D

# %%
#@title Caption

completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "user",
            "content": f'Design a 7-10 word signiture greeting for {prompt}. Make sure to include "Go Yellow Duckie!" at the end. Make sure to incorporate some funny emoji. Return a sentence only, without quotation mark.'
        }
    ]
)

cap = completion.choices[0].message.content
print(cap)
# Out:
# Quack-tastic vibes and square style! Go Yellow Duckie! 🐤🕶️🎨

# %%
# !pip install requests requests_oauthlib

# %%
import requests
from requests_oauthlib import OAuth1
import os
import logging

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='twitter_bot.log'
)

# Updated X API credentials
consumer_key = ''  # API Key
consumer_secret = ''  # API Key Secret
access_token = ''  # Access Token
access_token_secret = ''  # Access Token Secret

# Note: The bearer token (AAAAAAAAAAAAAAAAAAAAAFjizgEAAAAAnIjUdKla83Y5zCbCH%2BYsbIyJEyk%3DU4NY9THnSETczBRCDrjdH3kXKHBpzQub5w29ry21OsPR0Q1YNd)
# and client secret (AMyy16M5xtl7mfUtbiGLjx7J2ZD5888aX7w2W3QAtRVRQ-NPsN) are not needed for OAuth1

# Initialize OAuth1 authentication
auth = OAuth1(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)

class TwitterBot:
    def __init__(self, image_path, caption="test"):
        self.image_path = os.path.abspath(image_path)
        self.caption = caption
        self.media_upload_url = "https://upload.x.com/1.1/media/upload.json"
        self.tweet_url = "https://api.x.com/2/tweets"
        self.constant_text = "YD is Live ON XRPL NOW!"
        self.hashtags = "#YD #YellowDuckie #MEMECOIN"

    def upload_media(self, image_path):
        """Upload image to X and return media_id"""
        try:
            if not os.path.exists(image_path):
                raise FileNotFoundError(f"Image file not found: {image_path}")

            with open(image_path, "rb") as image_file:
                files = {"media": image_file}
                response = requests.post(
                    self.media_upload_url,
                    auth=auth,
                    files=files
                )
                response.raise_for_status()
                media_data = response.json()
                media_id = media_data["media_id_string"]
                logging.info(f"Media uploaded successfully. Media ID: {media_id}")
                return media_id
        except Exception as e:
            logging.error(f"Media upload failed: {str(e)}")
            raise

    def post_tweet(self):
        """Post a tweet with text and image"""
        try:
            # Check if the image file exists
            if not os.path.isfile(self.image_path):
                logging.error(f"Image file not found: {self.image_path}")
                print(f"Error: Image file not found: {self.image_path}")
                return

            # Upload the image
            media_id = self.upload_media(self.image_path)

            tweet_text = f"{self.caption}\n{self.constant_text}\n{self.hashtags}"
            payload = {
                "text": tweet_text,
                "media": {
                    "media_ids": [media_id]
                }
            }

            response = requests.post(
                self.tweet_url,
                auth=auth,
                json=payload
            )
            response.raise_for_status()

            tweet_data = response.json()
            logging.info(f"Tweet posted successfully! Tweet ID: {tweet_data['data']['id']}")
            logging.info(f"Tweet text: {tweet_data['data']['text']}")
            print(f"Tweet posted successfully! Tweet ID: {tweet_data['data']['id']}")
            print(f"Tweet text: {tweet_data['data']['text']}")

        except Exception as e:
            logging.error(f"Tweet posting failed: {str(e)}")
            print(f"Error: Tweet posting failed - {str(e)}")

def main():
    bot = TwitterBot(
        image_path="img.png",  # Current directory
        caption=cap     # Default caption
    )
    logging.info("Twitter Bot starting single execution...")
    print("Twitter Bot executing...")
    bot.post_tweet()
    logging.info("Twitter Bot completed execution")
    print("Execution completed")

if __name__ == "__main__":
    main()
